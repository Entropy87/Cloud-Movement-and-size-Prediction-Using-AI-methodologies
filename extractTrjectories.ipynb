# %%
from collections import defaultdict
import cv2
import numpy as np
from ultralytics import YOLO
from scipy.ndimage import center_of_mass
import csv
import os

# Load the YOLOv8 model
model = YOLO("best_osmu-e.pt")  # Ensure 'best.pt' is the correct path to your model

input_folder = "Dataset/Video"
output_folder = "Dataset/trajectories"

# YOLO prediction resolution (assuming 640x320)
yolo_width = 640
yolo_height = 320

# Store the track history
track_history = defaultdict(list)

# Function to process each video
def process_video(video_path, output_csv, output_video):
    cap = cv2.VideoCapture(video_path)

    # Check if video opened successfully
    if not cap.isOpened():
        print(f"Error: Cannot open video file {video_path}")
        return

    # Get the original video dimensions
    original_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    original_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

    # Initialize VideoWriter to save the annotated video
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')  # Codec for mp4 format
    out = cv2.VideoWriter(output_video, fourcc, cap.get(cv2.CAP_PROP_FPS), (original_width, original_height))

    # Define data structures for CSV
    combined_data = defaultdict(lambda: defaultdict(dict))  # combined_data[track_id][frame] = {...}

    frame_number = 0

    # Loop through the video frames
    while cap.isOpened():
        # Read a frame from the video
        success, frame = cap.read()
        frame_number += 1

        if not success:
            break

        # Run YOLOv8 tracking on the frame
        results = model.track(frame, persist=True, tracker="bytetrack.yaml")

        # Initialize masks and track_ids
        masks = []
        track_ids = []
        bboxes = []  # YOLO bounding boxes

        # Check if there are any detections
        if results and len(results) > 0 and results[0].boxes is not None and results[0].boxes.id is not None:
            masks = results[0].masks.data.cpu().numpy()
            track_ids = results[0].boxes.id.int().cpu().tolist()
            bboxes = results[0].boxes.xyxy.cpu().numpy()  # YOLO bounding boxes

        # Visualize the results on the frame
        annotated_frame = results[0].plot() if results and len(results) > 0 else frame.copy()

        for mask, track_id, bbox in zip(masks, track_ids, bboxes):
            if mask.sum() > 0:
                # Convert mask to binary image
                binary_mask = mask.astype(np.uint8)

                # Bounding box coordinates from YOLO
                top_left = (bbox[0], bbox[1])
                bottom_right = (bbox[2], bbox[3])
                top_right = (bbox[2], bbox[1])
                bottom_left = (bbox[0], bbox[3])

                # Scale bounding box coordinates based on the difference in resolution between YOLO input and original video
                x_scale_factor = original_width / yolo_width
                y_scale_factor = original_height / yolo_height

                # Scale bounding box coordinates
                top_left_scaled = (int(top_left[0] * x_scale_factor), int(top_left[1] * y_scale_factor))
                bottom_right_scaled = (int(bottom_right[0] * x_scale_factor), int(bottom_right[1] * y_scale_factor))

                # Calculate the center of mass of the mask
                mask_center_of_mass = center_of_mass(mask)
                center_y, center_x = mask_center_of_mass

                # Calculate the mask area (number of non-zero pixels)
                mask_area = np.sum(binary_mask)

                # Scale center of mass coordinates
                center_x_scaled = int(center_x * x_scale_factor)
                center_y_scaled = int(center_y * y_scale_factor)

                # Draw the center of mass (optional)
                cv2.circle(annotated_frame, (center_x_scaled, center_y_scaled), radius=5, color=(0, 255, 0), thickness=-1)

                # Log the tracking information: bounding box coordinates and area
                print(f"Frame {frame_number} - Track ID: {track_id}")
                print(f"  YOLO Bounding Box: Top Left: {top_left_scaled}, Bottom Right: {bottom_right_scaled}")
                print(f"  Mask Area: {mask_area}")
                print(f"  Center of Mass: X={center_x_scaled}, Y={center_y_scaled}")

                # Update track history with the center of mass
                track_history[track_id].append((float(center_x_scaled), float(center_y_scaled)))

                # Store data for CSV (including bounding box and mask area)
                combined_data[track_id][frame_number]['Center_X'] = center_x_scaled
                combined_data[track_id][frame_number]['Center_Y'] = center_y_scaled
                combined_data[track_id][frame_number]['Mask_Area'] = mask_area

        # Write the annotated frame to the output video
        out.write(annotated_frame)

        # Display the annotated frame
        cv2.imshow("YOLO Bounding Box Tracking", annotated_frame)

        if cv2.waitKey(1) & 0xFF == ord("q"):
            break

    # Release the video capture and writer objects, and close the display window
    cap.release()
    out.release()  # Release the VideoWriter
    cv2.destroyAllWindows()

    # Save combined data to CSV
    with open(output_csv, mode='w', newline='') as file:
        writer = csv.writer(file)
        # Header
        header = ["Track ID", "Frame", "Center X", "Center Y", "Mask Area"]
        writer.writerow(header)

        for track_id, frames in combined_data.items():
            for frame_num, data in frames.items():
                row = [
                    track_id,
                    frame_num,
                    data.get("Center_X", ""),
                    data.get("Center_Y", ""),
                    data.get("Mask_Area", "")
                ]
                writer.writerow(row)

    print(f"Combined tracking data saved to {output_csv}")


# Example of how you would process a folder of videos
video_files = [f for f in os.listdir(input_folder) if f.endswith(".mp4")]

for video_file in video_files:
    video_path = os.path.join(input_folder, video_file)
    output_csv = os.path.join(output_folder, f"{os.path.splitext(video_file)[0]}.csv")
    output_video = os.path.join(output_folder, f"{os.path.splitext(video_file)[0]}_annotated.mp4")
    process_video(video_path, output_csv, output_video)
# Out:
# 0: 320x640 6 Clouds, 1458.7ms
# Speed: 21.4ms preprocess, 1458.7ms inference, 57.3ms postprocess per image at shape (1, 3, 320, 640)
# Frame 1 - Track ID: 1
#   YOLO Bounding Box: Top Left: (4163, 1387), Bottom Right: (5751, 2796)
#   Mask Area: 12315
#   Center of Mass: X=1643, Y=703
# Frame 1 - Track ID: 2
#   YOLO Bounding Box: Top Left: (3669, 876), Bottom Right: (3963, 1038)
#   Mask Area: 418
#   Center of Mass: X=1264, Y=325
# Frame 1 - Track ID: 3
#   YOLO Bounding Box: Top Left: (3743, 1124), Bottom Right: (4130, 1233)
#   Mask Area: 406
#   Center of Mass: X=1320, Y=397
# Frame 1 - Track ID: 4
#   YOLO Bounding Box: Top Left: (3607, 1478), Bottom Right: (3823, 1548)
#   Mask Area: 145
#   Center of Mass: X=1239, Y=510
# Frame 1 - Track ID: 5
#   YOLO Bounding Box: Top Left: (2931, 2181), Bottom Right: (3682, 2485)
#   Mask Area: 780
#   Center of Mass: X=1120, Y=778
# Frame 1 - Track ID: 6
#   YOLO Bounding Box: Top Left: (4208, 2514), Bottom Right: (4529, 2794)
#   Mask Area: 407
#   Center of Mass: X=1451, Y=887
#
# 0: 320x640 6 Clouds, 787.9ms
# Speed: 4.3ms preprocess, 787.9ms inference, 15.0ms postprocess per image at shape (1, 3, 320, 640)
# Frame 2 - Track ID: 1
#   YOLO Bounding Box: Top Left: (4160, 1379), Bottom Right: (5757, 2796)
#   Mask Area: 12452
#   Center of Mass: X=1645, Y=700
# Frame 2 - Track ID: 2
#   YOLO Bounding Box: Top Left: (3679, 866), Bottom Right: (3985, 1035)
#   Mask Area: 529
#   Center of Mass: X=1276, Y=319
# Frame 2 - Track ID: 3
#   YOLO Bounding Box: Top Left: (3754, 1114), Bottom Right: (4135, 1221)
#   Mask Area: 626
#   Center of Mass: X=1317, Y=393
# Frame 2 - Track ID: 4
#   YOLO Bounding Box: Top Left: (3623, 1471), Bottom Right: (3852, 1545)
#   Mask Area: 236
#   Center of Mass: X=1241, Y=505
# Frame 2 - Track ID: 5
#   YOLO Bounding Box: Top Left: (2956, 2174), Bottom Right: (3733, 2487)
#   Mask Area: 889
#   Center of Mass: X=1125, Y=773
# Frame 2 - Track ID: 6
#   YOLO Bounding Box: Top Left: (4252, 2530), Bottom Right: (4554, 2793)
#   Mask Area: 402
#   Center of Mass: X=1463, Y=889
#
# 0: 320x640 6 Clouds, 824.4ms
# Speed: 2.0ms preprocess, 824.4ms inference, 12.0ms postprocess per image at shape (1, 3, 320, 640)
# Frame 3 - Track ID: 1
#   YOLO Bounding Box: Top Left: (4162, 1374), Bottom Right: (5760, 2796)
#   Mask Area: 12532
#   Center of Mass: X=1649, Y=699
# Frame 3 - Track ID: 2
#   YOLO Bounding Box: Top Left: (3685, 853), Bottom Right: (4009, 1031)
#   Mask Area: 538
#   Center of Mass: X=1279, Y=317
# Frame 3 - Track ID: 3
#   YOLO Bounding Box: Top Left: (3740, 1094), Bottom Right: (4167, 1215)
#   Mask Area: 550
#   Center of Mass: X=1314, Y=392
# Frame 3 - Track ID: 4
#   YOLO Bounding Box: Top Left: (3633, 1465), Bottom Right: (3883, 1545)
#   Mask Area: 277
#   Center of Mass: X=1247, Y=504
# Frame 3 - Track ID: 5
#   YOLO Bounding Box: Top Left: (3013, 2172), Bottom Right: (3818, 2498)
#   Mask Area: 887
#   Center of Mass: X=1143, Y=772
# Frame 3 - Track ID: 6
#   YOLO Bounding Box: Top Left: (4295, 2544), Bottom Right: (4581, 2794)
#   Mask Area: 369
#   Center of Mass: X=1475, Y=894
#
# 0: 320x640 8 Clouds, 761.7ms
# Speed: 3.0ms preprocess, 761.7ms inference, 11.5ms postprocess per image at shape (1, 3, 320, 640)
# Frame 4 - Track ID: 1
#   YOLO Bounding Box: Top Left: (4167, 1370), Bottom Right: (5760, 2795)
#   Mask Area: 12916
#   Center of Mass: X=1652, Y=696
# Frame 4 - Track ID: 2
#   YOLO Bounding Box: Top Left: (3698, 837), Bottom Right: (4042, 1026)
#   Mask Area: 524
#   Center of Mass: X=1279, Y=316
# Frame 4 - Track ID: 3
#   YOLO Bounding Box: Top Left: (3709, 1076), Bottom Right: (4195, 1214)
#   Mask Area: 685
#   Center of Mass: X=1317, Y=384
# Frame 4 - Track ID: 4
#   YOLO Bounding Box: Top Left: (3650, 1460), Bottom Right: (3910, 1543)
#   Mask Area: 354
#   Center of Mass: X=1260, Y=507
# Frame 4 - Track ID: 5
#   YOLO Bounding Box: Top Left: (3050, 2165), Bottom Right: (3868, 2497)
#   Mask Area: 874
#   Center of Mass: X=1162, Y=773
# Frame 4 - Track ID: 6
#   YOLO Bounding Box: Top Left: (4329, 2549), Bottom Right: (4610, 2795)
#   Mask Area: 396
#   Center of Mass: X=1482, Y=896
# Frame 4 - Track ID: 8
#   YOLO Bounding Box: Top Left: (2861, 1105), Bottom Right: (3538, 1311)
#   Mask Area: 1003
#   Center of Mass: X=1075, Y=407
# Frame 4 - Track ID: 9
#   YOLO Bounding Box: Top Left: (3534, 1032), Bottom Right: (3776, 1105)
#   Mask Area: 254
#   Center of Mass: X=1222, Y=362
#
# 0: 320x640 8 Clouds, 751.1ms
# Speed: 3.0ms preprocess, 751.1ms inference, 12.8ms postprocess per image at shape (1, 3, 320, 640)
# Frame 5 - Track ID: 1
#   YOLO Bounding Box: Top Left: (4167, 1362), Bottom Right: (5760, 2795)
#   Mask Area: 13008
#   Center of Mass: X=1656, Y=697
# Frame 5 - Track ID: 2
#   YOLO Bounding Box: Top Left: (3683, 830), Bottom Right: (4026, 1019)
#   Mask Area: 588
#   Center of Mass: X=1286, Y=311
# Frame 5 - Track ID: 3
#   YOLO Bounding Box: Top Left: (3654, 1045), Bottom Right: (4222, 1208)
#   Mask Area: 729
#   Center of Mass: X=1313, Y=379
# Frame 5 - Track ID: 4
#   YOLO Bounding Box: Top Left: (3666, 1450), Bottom Right: (3950, 1541)
#   Mask Area: 371
#   Center of Mass: X=1270, Y=506
# Frame 5 - Track ID: 5
#   YOLO Bounding Box: Top Left: (3082, 2154), Bottom Right: (3924, 2498)
#   Mask Area: 754
#   Center of Mass: X=1173, Y=769
# Frame 5 - Track ID: 6
#   YOLO Bounding Box: Top Left: (4325, 2536), Bottom Right: (4621, 2794)
#   Mask Area: 417
#   Center of Mass: X=1484, Y=894
# Frame 5 - Track ID: 8
#   YOLO Bounding Box: Top Left: (2906, 1099), Bottom Right: (3573, 1303)
#   Mask Area: 1083
#   Center of Mass: X=1083, Y=404
# Frame 5 - Track ID: 9
#   YOLO Bounding Box: Top Left: (3532, 1024), Bottom Right: (3790, 1101)
#   Mask Area: 189
#   Center of Mass: X=1221, Y=358
#
# 0: 320x640 7 Clouds, 757.0ms
# Speed: 3.0ms preprocess, 757.0ms inference, 13.0ms postprocess per image at shape (1, 3, 320, 640)
# Frame 6 - Track ID: 1
#   YOLO Bounding Box: Top Left: (4178, 1354), Bottom Right: (5760, 2792)
#   Mask Area: 13245
#   Center of Mass: X=1660, Y=697
# Frame 6 - Track ID: 2
#   YOLO Bounding Box: Top Left: (3678, 816), Bottom Right: (4036, 1014)
#   Mask Area: 556
#   Center of Mass: X=1285, Y=312
# Frame 6 - Track ID: 3
#   YOLO Bounding Box: Top Left: (3565, 1014), Bottom Right: (4223, 1203)
#   Mask Area: 964
#   Center of Mass: X=1294, Y=370
# Frame 6 - Track ID: 4
#   YOLO Bounding Box: Top Left: (3676, 1436), Bottom Right: (3996, 1538)
#   Mask Area: 515
#   Center of Mass: X=1275, Y=501
# Frame 6 - Track ID: 5
#   YOLO Bounding Box: Top Left: (3121, 2145), Bottom Right: (3975, 2497)
#   Mask Area: 794
#   Center of Mass: X=1181, Y=764
# Frame 6 - Track ID: 6
#   YOLO Bounding Box: Top Left: (4369, 2592), Bottom Right: (4606, 2794)
#   Mask Area: 249
#   Center of Mass: X=1494, Y=903
# Frame 6 - Track ID: 8
#   YOLO Bounding Box: Top Left: (2920, 1087), Bottom Right: (3615, 1299)
#   Mask Area: 1170
#   Center of Mass: X=1090, Y=404
#
# 0: 320x640 7 Clouds, 748.7ms
# Speed: 4.0ms preprocess, 748.7ms inference, 11.0ms postprocess per image at shape (1, 3, 320, 640)
# Frame 7 - Track ID: 1
#   YOLO Bounding Box: Top Left: (4171, 1341), Bottom Right: (5760, 2791)
#   Mask Area: 13052
#   Center of Mass: X=1662, Y=698
# Frame 7 - Track ID: 2
#   YOLO Bounding Box: Top Left: (3674, 805), Bottom Right: (4043, 1010)
#   Mask Area: 658
#   Center of Mass: X=1289, Y=311
# Frame 7 - Track ID: 3
#   YOLO Bounding Box: Top Left: (3543, 999), Bottom Right: (4224, 1195)
#   Mask Area: 996
#   Center of Mass: X=1299, Y=367
# Frame 7 - Track ID: 4
#   YOLO Bounding Box: Top Left: (3687, 1424), Bottom Right: (4040, 1537)
#   Mask Area: 537
#   Center of Mass: X=1289, Y=500
# Frame 7 - Track ID: 5
#   YOLO Bounding Box: Top Left: (3173, 2142), Bottom Right: (4005, 2489)
#   Mask Area: 652
#   Center of Mass: X=1189, Y=759
# Frame 7 - Track ID: 6
#   YOLO Bounding Box: Top Left: (4421, 2617), Bottom Right: (4632, 2793)
#   Mask Area: 175
#   Center of Mass: X=1510, Y=909
# Frame 7 - Track ID: 8
#   YOLO Bounding Box: Top Left: (2921, 1077), Bottom Right: (3669, 1307)
#   Mask Area: 1339
#   Center of Mass: X=1099, Y=401
#
# 0: 320x640 6 Clouds, 745.3ms
# Speed: 3.0ms preprocess, 745.3ms inference, 9.0ms postprocess per image at shape (1, 3, 320, 640)
# Frame 8 - Track ID: 1
#   YOLO Bounding Box: Top Left: (4167, 1320), Bottom Right: (5760, 2792)
#   Mask Area: 13137
#   Center of Mass: X=1665, Y=697
# Frame 8 - Track ID: 2
#   YOLO Bounding Box: Top Left: (3688, 796), Bottom Right: (4057, 1002)
#   Mask Area: 616
#   Center of Mass: X=1294, Y=308
# Frame 8 - Track ID: 3
#   YOLO Bounding Box: Top Left: (3552, 995), Bottom Right: (4227, 1187)
#   Mask Area: 1160
#   Center of Mass: X=1307, Y=366
# Frame 8 - Track ID: 4
#   YOLO Bounding Box: Top Left: (3690, 1410), Bottom Right: (4081, 1535)
#   Mask Area: 546
#   Center of Mass: X=1297, Y=498
# Frame 8 - Track ID: 5
#   YOLO Bounding Box: Top Left: (3223, 2136), Bottom Right: (4049, 2485)
#   Mask Area: 664
#   Center of Mass: X=1218, Y=766
# Frame 8 - Track ID: 8
#   YOLO Bounding Box: Top Left: (2922, 1064), Bottom Right: (3722, 1312)
#   Mask Area: 1471
#   Center of Mass: X=1105, Y=401
#
# 0: 320x640 6 Clouds, 750.9ms
# Speed: 3.0ms preprocess, 750.9ms inference, 10.0ms postprocess per image at shape (1, 3, 320, 640)
# Frame 9 - Track ID: 1
#   YOLO Bounding Box: Top Left: (4163, 1296), Bottom Right: (5760, 2792)
#   Mask Area: 13214
#   Center of Mass: X=1666, Y=697
# Frame 9 - Track ID: 2
#   YOLO Bounding Box: Top Left: (3690, 786), Bottom Right: (4041, 981)
#   Mask Area: 499
#   Center of Mass: X=1286, Y=305
# Frame 9 - Track ID: 3
#   YOLO Bounding Box: Top Left: (3551, 987), Bottom Right: (4246, 1184)
#   Mask Area: 1156
#   Center of Mass: X=1313, Y=365
# Frame 9 - Track ID: 4
#   YOLO Bounding Box: Top Left: (3701, 1399), Bottom Right: (4122, 1534)
#   Mask Area: 621
#   Center of Mass: X=1302, Y=492
# Frame 9 - Track ID: 5
#   YOLO Bounding Box: Top Left: (3270, 2130), Bottom Right: (4130, 2499)
#   Mask Area: 745
#   Center of Mass: X=1230, Y=766
# Frame 9 - Track ID: 8
#   YOLO Bounding Box: Top Left: (2932, 1051), Bottom Right: (3754, 1308)
#   Mask Area: 1499
#   Center of Mass: X=1114, Y=399
#
# 0: 320x640 6 Clouds, 743.9ms
# Speed: 3.0ms preprocess, 743.9ms inference, 19.0ms postprocess per image at shape (1, 3, 320, 640)
# Frame 10 - Track ID: 1
#   YOLO Bounding Box: Top Left: (4168, 1280), Bottom Right: (5760, 2793)
#   Mask Area: 13156
#   Center of Mass: X=1670, Y=699
# Frame 10 - Track ID: 2
#   YOLO Bounding Box: Top Left: (3700, 797), Bottom Right: (4023, 976)
#   Mask Area: 342
#   Center of Mass: X=1277, Y=303
# Frame 10 - Track ID: 3
#   YOLO Bounding Box: Top Left: (3520, 958), Bottom Right: (4294, 1179)
#   Mask Area: 1130
#   Center of Mass: X=1316, Y=359
# Frame 10 - Track ID: 4
#   YOLO Bounding Box: Top Left: (3721, 1388), Bottom Right: (4162, 1530)
#   Mask Area: 648
#   Center of Mass: X=1312, Y=488
# Frame 10 - Track ID: 8
#   YOLO Bounding Box: Top Left: (2917, 1039), Bottom Right: (3778, 1310)
#   Mask Area: 1783
#   Center of Mass: X=1118, Y=394
# Frame 10 - Track ID: 11
#   YOLO Bounding Box: Top Left: (4208, 1835), Bottom Right: (4414, 1996)
#   Mask Area: 387
#   Center of Mass: X=1440, Y=646
#
# 0: 320x640 4 Clouds, 742.8ms
# Speed: 2.0ms preprocess, 742.8ms inference, 11.0ms postprocess per image at shape (1, 3, 320, 640)
# Frame 11 - Track ID: 1
#   YOLO Bounding Box: Top Left: (4185, 1284), Bottom Right: (5760, 2793)
#   Mask Area: 13153
#   Center of Mass: X=1674, Y=701
# Frame 11 - Track ID: 4
#   YOLO Bounding Box: Top Left: (3736, 1375), Bottom Right: (4202, 1525)
#   Mask Area: 620
#   Center of Mass: X=1322, Y=484
# Frame 11 - Track ID: 8
#   YOLO Bounding Box: Top Left: (2895, 906), Bottom Right: (4186, 1317)
#   Mask Area: 3243
#   Center of Mass: X=1209, Y=374
# Frame 11 - Track ID: 11
#   YOLO Bounding Box: Top Left: (4213, 1829), Bottom Right: (4435, 2003)
#   Mask Area: 399
#   Center of Mass: X=1444, Y=644
#
# 0: 320x640 5 Clouds, 748.2ms
# Speed: 3.0ms preprocess, 748.2ms inference, 10.0ms postprocess per image at shape (1, 3, 320, 640)
# Frame 12 - Track ID: 1
#   YOLO Bounding Box: Top Left: (4190, 1294), Bottom Right: (5760, 2795)
#   Mask Area: 13518
#   Center of Mass: X=1674, Y=701
# Frame 12 - Track ID: 4
#   YOLO Bounding Box: Top Left: (3744, 1363), Bottom Right: (4252, 1527)
#   Mask Area: 712
#   Center of Mass: X=1325, Y=478
# Frame 12 - Track ID: 8
#   YOLO Bounding Box: Top Left: (2974, 911), Bottom Right: (4274, 1323)
#   Mask Area: 3060
#   Center of Mass: X=1203, Y=381
# Frame 12 - Track ID: 11
#   YOLO Bounding Box: Top Left: (4223, 1820), Bottom Right: (4472, 2013)
#   Mask Area: 417
#   Center of Mass: X=1451, Y=642
# Frame 12 - Track ID: 2
#   YOLO Bounding Box: Top Left: (3728, 830), Bottom Right: (3948, 948)
#   Mask Area: 284
#   Center of Mass: X=1269, Y=302
#
# 0: 320x640 5 Clouds, 742.6ms
# Speed: 3.0ms preprocess, 742.6ms inference, 6.0ms postprocess per image at shape (1, 3, 320, 640)
# Frame 13 - Track ID: 1
#   YOLO Bounding Box: Top Left: (4193, 1302), Bottom Right: (5760, 2792)
#   Mask Area: 13158
#   Center of Mass: X=1676, Y=703
# Frame 13 - Track ID: 4
#   YOLO Bounding Box: Top Left: (3742, 1347), Bottom Right: (4288, 1525)
#   Mask Area: 718
#   Center of Mass: X=1338, Y=475
# Frame 13 - Track ID: 8
#   YOLO Bounding Box: Top Left: (3011, 921), Bottom Right: (4314, 1333)
#   Mask Area: 3143
#   Center of Mass: X=1207, Y=378
# Frame 13 - Track ID: 12
#   YOLO Bounding Box: Top Left: (4185, 2525), Bottom Right: (4539, 2743)
#   Mask Area: 248
#   Center of Mass: X=1462, Y=887
# Frame 13 - Track ID: 2
#   YOLO Bounding Box: Top Left: (3740, 835), Bottom Right: (3944, 940)
#   Mask Area: 244
#   Center of Mass: X=1272, Y=302
#
# 0: 320x640 4 Clouds, 744.6ms
# Speed: 2.0ms preprocess, 744.6ms inference, 6.0ms postprocess per image at shape (1, 3, 320, 640)
# Frame 14 - Track ID: 1
#   YOLO Bounding Box: Top Left: (4214, 1316), Bottom Right: (5760, 2790)
#   Mask Area: 13392
#   Center of Mass: X=1677, Y=701
# Frame 14 - Track ID: 4
#   YOLO Bounding Box: Top Left: (3759, 1337), Bottom Right: (4310, 1517)
#   Mask Area: 686
#   Center of Mass: X=1344, Y=472
# Frame 14 - Track ID: 8
#   YOLO Bounding Box: Top Left: (2927, 860), Bottom Right: (4426, 1343)
#   Mask Area: 3358
#   Center of Mass: X=1209, Y=375
# Frame 14 - Track ID: 12
#   YOLO Bounding Box: Top Left: (4182, 2510), Bottom Right: (4592, 2765)
#   Mask Area: 218
#   Center of Mass: X=1463, Y=882
#
# 0: 320x640 4 Clouds, 844.9ms
# Speed: 2.0ms preprocess, 844.9ms inference, 7.0ms postprocess per image at shape (1, 3, 320, 640)
# Frame 15 - Track ID: 1
#   YOLO Bounding Box: Top Left: (4233, 1329), Bottom Right: (5760, 2789)
#   Mask Area: 13675
#   Center of Mass: X=1679, Y=699
# Frame 15 - Track ID: 4
#   YOLO Bounding Box: Top Left: (3774, 1324), Bottom Right: (4352, 1514)
#   Mask Area: 847
#   Center of Mass: X=1350, Y=466
# Frame 15 - Track ID: 8
#   YOLO Bounding Box: Top Left: (2955, 875), Bottom Right: (4428, 1353)
#   Mask Area: 3486
#   Center of Mass: X=1214, Y=378
# Frame 15 - Track ID: 12
#   YOLO Bounding Box: Top Left: (4224, 2519), Bottom Right: (4655, 2788)
#   Mask Area: 221
#   Center of Mass: X=1484, Y=892
#
# 0: 320x640 4 Clouds, 796.9ms
# Speed: 2.0ms preprocess, 796.9ms inference, 7.3ms postprocess per image at shape (1, 3, 320, 640)
# Frame 16 - Track ID: 1
#   YOLO Bounding Box: Top Left: (4239, 1331), Bottom Right: (5760, 2792)
#   Mask Area: 13474
#   Center of Mass: X=1683, Y=700
# Frame 16 - Track ID: 4
#   YOLO Bounding Box: Top Left: (3827, 1314), Bottom Right: (4363, 1486)
#   Mask Area: 893
#   Center of Mass: X=1364, Y=465
# Frame 16 - Track ID: 8
#   YOLO Bounding Box: Top Left: (2961, 876), Bottom Right: (4442, 1362)
#   Mask Area: 3588
#   Center of Mass: X=1220, Y=375
# Frame 16 - Track ID: 12
#   YOLO Bounding Box: Top Left: (4273, 2533), Bottom Right: (4686, 2793)
#   Mask Area: 143
#   Center of Mass: X=1492, Y=891
#
# 0: 320x640 3 Clouds, 763.6ms
# Speed: 3.0ms preprocess, 763.6ms inference, 6.0ms postprocess per image at shape (1, 3, 320, 640)
# Frame 17 - Track ID: 1
#   YOLO Bounding Box: Top Left: (4252, 1326), Bottom Right: (5760, 2791)
#   Mask Area: 13760
#   Center of Mass: X=1687, Y=696
# Frame 17 - Track ID: 8
#   YOLO Bounding Box: Top Left: (2976, 928), Bottom Right: (4467, 1423)
#   Mask Area: 2895
#   Center of Mass: X=1213, Y=408
# Frame 17 - Track ID: 3
#   YOLO Bounding Box: Top Left: (3549, 873), Bottom Right: (4419, 1132)
#   Mask Area: 1229
#   Center of Mass: X=1329, Y=337
#
# 0: 320x640 3 Clouds, 760.8ms
# Speed: 2.0ms preprocess, 760.8ms inference, 7.0ms postprocess per image at shape (1, 3, 320, 640)
# Frame 18 - Track ID: 1
#   YOLO Bounding Box: Top Left: (4263, 1320), Bottom Right: (5760, 2790)
#   Mask Area: 14110
#   Center of Mass: X=1691, Y=696
# Frame 18 - Track ID: 8
#   YOLO Bounding Box: Top Left: (2881, 880), Bottom Right: (4534, 1439)
#   Mask Area: 3936
#   Center of Mass: X=1240, Y=386
# Frame 18 - Track ID: 3
#   YOLO Bounding Box: Top Left: (3572, 860), Bottom Right: (4429, 1124)
#   Mask Area: 1295
#   Center of Mass: X=1324, Y=332
#
# 0: 320x640 2 Clouds, 753.9ms
# Speed: 2.0ms preprocess, 753.9ms inference, 9.0ms postprocess per image at shape (1, 3, 320, 640)
# Frame 19 - Track ID: 1
#   YOLO Bounding Box: Top Left: (4256, 1304), Bottom Right: (5760, 2794)
#   Mask Area: 14130
#   Center of Mass: X=1695, Y=697
# Frame 19 - Track ID: 8
#   YOLO Bounding Box: Top Left: (2893, 857), Bottom Right: (4529, 1419)
#   Mask Area: 4131
#   Center of Mass: X=1249, Y=382
#
# 0: 320x640 3 Clouds, 786.8ms
# Speed: 2.0ms preprocess, 786.8ms inference, 7.0ms postprocess per image at shape (1, 3, 320, 640)
# Frame 20 - Track ID: 1
#   YOLO Bounding Box: Top Left: (4273, 1327), Bottom Right: (5760, 2792)
#   Mask Area: 14007
#   Center of Mass: X=1701, Y=699
# Frame 20 - Track ID: 8
#   YOLO Bounding Box: Top Left: (2918, 840), Bottom Right: (4537, 1406)
#   Mask Area: 3903
#   Center of Mass: X=1245, Y=387
# Frame 20 - Track ID: 13
#   YOLO Bounding Box: Top Left: (4293, 2421), Bottom Right: (4632, 2696)
#   Mask Area: 223
#   Center of Mass: X=1493, Y=859
#
# 0: 320x640 3 Clouds, 806.6ms
# Speed: 2.0ms preprocess, 806.6ms inference, 9.0ms postprocess per image at shape (1, 3, 320, 640)
# Frame 21 - Track ID: 1
#   YOLO Bounding Box: Top Left: (4278, 1341), Bottom Right: (5760, 2792)
#   Mask Area: 13897
#   Center of Mass: X=1704, Y=698
# Frame 21 - Track ID: 8
#   YOLO Bounding Box: Top Left: (2947, 825), Bottom Right: (4557, 1398)
#   Mask Area: 4520
#   Center of Mass: X=1260, Y=382
# Frame 21 - Track ID: 13
#   YOLO Bounding Box: Top Left: (4328, 2426), Bottom Right: (4684, 2716)
#   Mask Area: 171
#   Center of Mass: X=1501, Y=856
#
# 0: 320x640 2 Clouds, 754.8ms
# Speed: 2.0ms preprocess, 754.8ms inference, 8.0ms postprocess per image at shape (1, 3, 320, 640)
# Frame 22 - Track ID: 1
#   YOLO Bounding Box: Top Left: (4274, 1347), Bottom Right: (5760, 2791)
#   Mask Area: 13731
#   Center of Mass: X=1706, Y=697
# Frame 22 - Track ID: 8
#   YOLO Bounding Box: Top Left: (2965, 816), Bottom Right: (4572, 1399)
#   Mask Area: 4902
#   Center of Mass: X=1265, Y=383
#
# 0: 320x640 3 Clouds, 756.5ms
# Speed: 2.0ms preprocess, 756.5ms inference, 9.0ms postprocess per image at shape (1, 3, 320, 640)
# Frame 23 - Track ID: 1
#   YOLO Bounding Box: Top Left: (4278, 1360), Bottom Right: (5760, 2793)
#   Mask Area: 13576
#   Center of Mass: X=1706, Y=694
# Frame 23 - Track ID: 8
#   YOLO Bounding Box: Top Left: (3101, 899), Bottom Right: (4471, 1393)
#   Mask Area: 3351
#   Center of Mass: X=1242, Y=404
# Frame 23 - Track ID: 3
#   YOLO Bounding Box: Top Left: (3581, 822), Bottom Right: (4459, 1104)
#   Mask Area: 1554
#   Center of Mass: X=1332, Y=326
#
# 0: 320x640 3 Clouds, 757.4ms
# Speed: 3.0ms preprocess, 757.4ms inference, 7.0ms postprocess per image at shape (1, 3, 320, 640)
# Frame 24 - Track ID: 1
#   YOLO Bounding Box: Top Left: (4280, 1351), Bottom Right: (5760, 2792)
#   Mask Area: 13526
#   Center of Mass: X=1707, Y=693
# Frame 24 - Track ID: 8
#   YOLO Bounding Box: Top Left: (3167, 936), Bottom Right: (4445, 1393)
#   Mask Area: 3513
#   Center of Mass: X=1250, Y=401
# Frame 24 - Track ID: 3
#   YOLO Bounding Box: Top Left: (3597, 819), Bottom Right: (4456, 1102)
#   Mask Area: 1571
#   Center of Mass: X=1338, Y=326
#
# 0: 320x640 2 Clouds, 751.4ms
# Speed: 2.0ms preprocess, 751.4ms inference, 7.0ms postprocess per image at shape (1, 3, 320, 640)
# Frame 25 - Track ID: 1
#   YOLO Bounding Box: Top Left: (4252, 1348), Bottom Right: (5751, 2793)
#   Mask Area: 13236
#   Center of Mass: X=1711, Y=694
# Frame 25 - Track ID: 8
#   YOLO Bounding Box: Top Left: (3067, 850), Bottom Right: (4582, 1402)
#   Mask Area: 4728
#   Center of Mass: X=1276, Y=380
# Combined tracking data saved to Dataset/trajectories\1.csv
#
# 0: 320x640 1 Cloud, 778.5ms
# Speed: 2.0ms preprocess, 778.5ms inference, 35.5ms postprocess per image at shape (1, 3, 320, 640)
# Frame 1 - Track ID: 1
#   YOLO Bounding Box: Top Left: (4322, 1436), Bottom Right: (5735, 2792)
#   Mask Area: 4925
#   Center of Mass: X=1742, Y=824
#
# 0: 320x640 11 Clouds, 821.5ms
# Speed: 3.0ms preprocess, 821.5ms inference, 28.0ms postprocess per image at shape (1, 3, 320, 640)
# Frame 2 - Track ID: 1
#   YOLO Bounding Box: Top Left: (4360, 1479), Bottom Right: (5734, 2792)
#   Mask Area: 3866
#   Center of Mass: X=1745, Y=803
# Frame 2 - Track ID: 14
#   YOLO Bounding Box: Top Left: (34, 1491), Bottom Right: (2096, 2794)
#   Mask Area: 8523
#   Center of Mass: X=359, Y=723
# Frame 2 - Track ID: 15
#   YOLO Bounding Box: Top Left: (977, 412), Bottom Right: (1622, 793)
#   Mask Area: 1971
#   Center of Mass: X=427, Y=209
# Frame 2 - Track ID: 16
#   YOLO Bounding Box: Top Left: (1856, 773), Bottom Right: (3460, 2019)
#   Mask Area: 12246
#   Center of Mass: X=878, Y=520
# Frame 2 - Track ID: 17
#   YOLO Bounding Box: Top Left: (659, 529), Bottom Right: (961, 759)
#   Mask Area: 450
#   Center of Mass: X=273, Y=220
# Frame 2 - Track ID: 18
#   YOLO Bounding Box: Top Left: (4957, 699), Bottom Right: (5246, 1065)
#   Mask Area: 716
#   Center of Mass: X=1703, Y=308
# Frame 2 - Track ID: 19
#   YOLO Bounding Box: Top Left: (119, 0), Bottom Right: (572, 194)
#   Mask Area: 507
#   Center of Mass: X=111, Y=30
# Frame 2 - Track ID: 20
#   YOLO Bounding Box: Top Left: (2325, 14), Bottom Right: (2945, 281)
#   Mask Area: 1154
#   Center of Mass: X=890, Y=52
# Frame 2 - Track ID: 21
#   YOLO Bounding Box: Top Left: (5590, 1115), Bottom Right: (5715, 1374)
#   Mask Area: 388
#   Center of Mass: X=1886, Y=409
# Frame 2 - Track ID: 22
#   YOLO Bounding Box: Top Left: (1841, 653), Bottom Right: (2138, 1098)
#   Mask Area: 820
#   Center of Mass: X=662, Y=302
# Frame 2 - Track ID: 24
#   YOLO Bounding Box: Top Left: (1822, 10), Bottom Right: (2387, 173)
#   Mask Area: 855
#   Center of Mass: X=703, Y=24
#
# 0: 320x640 12 Clouds, 759.7ms
# Speed: 2.0ms preprocess, 759.7ms inference, 28.0ms postprocess per image at shape (1, 3, 320, 640)
# Frame 3 - Track ID: 1
#   YOLO Bounding Box: Top Left: (4381, 1509), Bottom Right: (5732, 2795)
#   Mask Area: 2810
#   Center of Mass: X=1728, Y=755
# Frame 3 - Track ID: 14
#   YOLO Bounding Box: Top Left: (52, 1517), Bottom Right: (2078, 2796)
#   Mask Area: 8545
#   Center of Mass: X=359, Y=725
# Frame 3 - Track ID: 15
#   YOLO Bounding Box: Top Left: (968, 405), Bottom Right: (1618, 789)
#   Mask Area: 1921
#   Center of Mass: X=423, Y=208
# Frame 3 - Track ID: 16
#   YOLO Bounding Box: Top Left: (1805, 688), Bottom Right: (3518, 2022)
#   Mask Area: 12457
#   Center of Mass: X=877, Y=517
# Frame 3 - Track ID: 17
#   YOLO Bounding Box: Top Left: (659, 527), Bottom Right: (958, 755)
#   Mask Area: 436
#   Center of Mass: X=271, Y=219
# Frame 3 - Track ID: 18
#   YOLO Bounding Box: Top Left: (4959, 697), Bottom Right: (5252, 1068)
#   Mask Area: 712
#   Center of Mass: X=1702, Y=308
# Frame 3 - Track ID: 19
#   YOLO Bounding Box: Top Left: (94, 4), Bottom Right: (545, 198)
#   Mask Area: 514
#   Center of Mass: X=104, Y=30
# Frame 3 - Track ID: 20
#   YOLO Bounding Box: Top Left: (2315, 13), Bottom Right: (2955, 289)
#   Mask Area: 1157
#   Center of Mass: X=892, Y=52
# Frame 3 - Track ID: 21
#   YOLO Bounding Box: Top Left: (5594, 1114), Bottom Right: (5718, 1370)
#   Mask Area: 333
#   Center of Mass: X=1883, Y=409
# Frame 3 - Track ID: 22
#   YOLO Bounding Box: Top Left: (1859, 659), Bottom Right: (2143, 1085)
#   Mask Area: 748
#   Center of Mass: X=666, Y=303
# Frame 3 - Track ID: 24
#   YOLO Bounding Box: Top Left: (1824, 12), Bottom Right: (2371, 170)
#   Mask Area: 787
#   Center of Mass: X=695, Y=25
# Frame 3 - Track ID: 25
#   YOLO Bounding Box: Top Left: (0, 180), Bottom Right: (493, 937)
#   Mask Area: 2243
#   Center of Mass: X=61, Y=161
#
# 0: 320x640 13 Clouds, 762.0ms
# Speed: 2.0ms preprocess, 762.0ms inference, 32.4ms postprocess per image at shape (1, 3, 320, 640)
# Frame 4 - Track ID: 1
#   YOLO Bounding Box: Top Left: (4392, 1514), Bottom Right: (5741, 2796)
#   Mask Area: 2358
#   Center of Mass: X=1730, Y=757
# Frame 4 - Track ID: 14
#   YOLO Bounding Box: Top Left: (590, 1820), Bottom Right: (2132, 2794)
#   Mask Area: 4632
#   Center of Mass: X=461, Y=816
# Frame 4 - Track ID: 15
#   YOLO Bounding Box: Top Left: (951, 406), Bottom Right: (1593, 786)
#   Mask Area: 1625
#   Center of Mass: X=417, Y=210
# Frame 4 - Track ID: 16
#   YOLO Bounding Box: Top Left: (1815, 706), Bottom Right: (3506, 2026)
#   Mask Area: 12616
#   Center of Mass: X=884, Y=521
# Frame 4 - Track ID: 17
#   YOLO Bounding Box: Top Left: (663, 527), Bottom Right: (953, 748)
#   Mask Area: 395
#   Center of Mass: X=267, Y=216
# Frame 4 - Track ID: 18
#   YOLO Bounding Box: Top Left: (4958, 701), Bottom Right: (5251, 1072)
#   Mask Area: 725
#   Center of Mass: X=1701, Y=310
# Frame 4 - Track ID: 19
#   YOLO Bounding Box: Top Left: (70, 5), Bottom Right: (531, 204)
#   Mask Area: 516
#   Center of Mass: X=103, Y=31
# Frame 4 - Track ID: 20
#   YOLO Bounding Box: Top Left: (2316, 13), Bottom Right: (2948, 286)
#   Mask Area: 1167
#   Center of Mass: X=894, Y=51
# Frame 4 - Track ID: 21
#   YOLO Bounding Box: Top Left: (5595, 1112), Bottom Right: (5717, 1364)
#   Mask Area: 324
#   Center of Mass: X=1882, Y=412
# Frame 4 - Track ID: 22
#   YOLO Bounding Box: Top Left: (1904, 753), Bottom Right: (2127, 1083)
#   Mask Area: 503
#   Center of Mass: X=671, Y=317
# Frame 4 - Track ID: 24
#   YOLO Bounding Box: Top Left: (1826, 12), Bottom Right: (2351, 163)
#   Mask Area: 717
#   Center of Mass: X=687, Y=24
# Frame 4 - Track ID: 25
#   YOLO Bounding Box: Top Left: (0, 173), Bottom Right: (495, 947)
#   Mask Area: 2301
#   Center of Mass: X=63, Y=161
# Frame 4 - Track ID: 26
#   YOLO Bounding Box: Top Left: (2774, 2063), Bottom Right: (3095, 2217)
#   Mask Area: 494
#   Center of Mass: X=959, Y=717
#
# 0: 320x640 15 Clouds, 771.3ms
# Speed: 3.0ms preprocess, 771.3ms inference, 36.0ms postprocess per image at shape (1, 3, 320, 640)
# Frame 5 - Track ID: 1
#   YOLO Bounding Box: Top Left: (4395, 1509), Bottom Right: (5747, 2794)
#   Mask Area: 1987
#   Center of Mass: X=1744, Y=754
# Frame 5 - Track ID: 14
#   YOLO Bounding Box: Top Left: (193, 1580), Bottom Right: (2120, 2796)
#   Mask Area: 8691
#   Center of Mass: X=379, Y=727
# Frame 5 - Track ID: 15
#   YOLO Bounding Box: Top Left: (922, 402), Bottom Right: (1571, 786)
#   Mask Area: 1578
#   Center of Mass: X=413, Y=207
# Frame 5 - Track ID: 16
#   YOLO Bounding Box: Top Left: (1982, 889), Bottom Right: (3444, 2025)
#   Mask Area: 11738
#   Center of Mass: X=891, Y=526
# Frame 5 - Track ID: 17
#   YOLO Bounding Box: Top Left: (662, 521), Bottom Right: (952, 742)
#   Mask Area: 370
#   Center of Mass: X=264, Y=214
# Frame 5 - Track ID: 18
#   YOLO Bounding Box: Top Left: (4961, 740), Bottom Right: (5227, 1075)
#   Mask Area: 725
#   Center of Mass: X=1700, Y=310
# Frame 5 - Track ID: 19
#   YOLO Bounding Box: Top Left: (38, 3), Bottom Right: (549, 226)
#   Mask Area: 537
#   Center of Mass: X=106, Y=32
# Frame 5 - Track ID: 20
#   YOLO Bounding Box: Top Left: (2364, 15), Bottom Right: (2982, 283)
#   Mask Area: 1126
#   Center of Mass: X=898, Y=51
# Frame 5 - Track ID: 21
#   YOLO Bounding Box: Top Left: (5595, 1108), Bottom Right: (5719, 1363)
#   Mask Area: 332
#   Center of Mass: X=1883, Y=412
# Frame 5 - Track ID: 22
#   YOLO Bounding Box: Top Left: (1993, 913), Bottom Right: (2119, 1092)
#   Mask Area: 347
#   Center of Mass: X=683, Y=338
# Frame 5 - Track ID: 24
#   YOLO Bounding Box: Top Left: (1822, 12), Bottom Right: (2316, 154)
#   Mask Area: 679
#   Center of Mass: X=684, Y=24
# Frame 5 - Track ID: 25
#   YOLO Bounding Box: Top Left: (37, 166), Bottom Right: (434, 768)
#   Mask Area: 1753
#   Center of Mass: X=59, Y=139
# Frame 5 - Track ID: 26
#   YOLO Bounding Box: Top Left: (2790, 2072), Bottom Right: (3076, 2209)
#   Mask Area: 515
#   Center of Mass: X=963, Y=719
# Frame 5 - Track ID: 27
#   YOLO Bounding Box: Top Left: (53, 1513), Bottom Right: (1069, 1996)
#   Mask Area: 3119
#   Center of Mass: X=186, Y=586
# Frame 5 - Track ID: 28
#   YOLO Bounding Box: Top Left: (3540, 2531), Bottom Right: (4269, 2796)
#   Mask Area: 1814
#   Center of Mass: X=1289, Y=899
#
# 0: 320x640 17 Clouds, 759.7ms
# Speed: 2.4ms preprocess, 759.7ms inference, 27.5ms postprocess per image at shape (1, 3, 320, 640)
# Frame 6 - Track ID: 1
#   YOLO Bounding Box: Top Left: (4401, 1505), Bottom Right: (5758, 2794)
#   Mask Area: 2298
#   Center of Mass: X=1726, Y=778
# Frame 6 - Track ID: 14
#   YOLO Bounding Box: Top Left: (122, 1529), Bottom Right: (2135, 2796)
#   Mask Area: 8596
#   Center of Mass: X=383, Y=725
# Frame 6 - Track ID: 15
#   YOLO Bounding Box: Top Left: (930, 396), Bottom Right: (1583, 784)
#   Mask Area: 1632
#   Center of Mass: X=415, Y=207
# Frame 6 - Track ID: 16
#   YOLO Bounding Box: Top Left: (2018, 934), Bottom Right: (3457, 2049)
#   Mask Area: 12391
#   Center of Mass: X=893, Y=524
# Frame 6 - Track ID: 17
#   YOLO Bounding Box: Top Left: (660, 515), Bottom Right: (946, 733)
#   Mask Area: 354
#   Center of Mass: X=262, Y=211
# Frame 6 - Track ID: 18
#   YOLO Bounding Box: Top Left: (4956, 756), Bottom Right: (5215, 1080)
#   Mask Area: 752
#   Center of Mass: X=1698, Y=310
# Frame 6 - Track ID: 19
#   YOLO Bounding Box: Top Left: (25, 6), Bottom Right: (544, 234)
#   Mask Area: 550
#   Center of Mass: X=105, Y=32
# Frame 6 - Track ID: 20
#   YOLO Bounding Box: Top Left: (2385, 18), Bottom Right: (2987, 280)
#   Mask Area: 925
#   Center of Mass: X=897, Y=58
# Frame 6 - Track ID: 21
#   YOLO Bounding Box: Top Left: (5599, 1106), Bottom Right: (5722, 1358)
#   Mask Area: 311
#   Center of Mass: X=1882, Y=411
# Frame 6 - Track ID: 24
#   YOLO Bounding Box: Top Left: (1801, 13), Bottom Right: (2284, 152)
#   Mask Area: 603
#   Center of Mass: X=676, Y=22
# Frame 6 - Track ID: 25
#   YOLO Bounding Box: Top Left: (43, 150), Bottom Right: (413, 707)
#   Mask Area: 1835
#   Center of Mass: X=53, Y=138
# Frame 6 - Track ID: 26
#   YOLO Bounding Box: Top Left: (2786, 2079), Bottom Right: (3057, 2207)
#   Mask Area: 511
#   Center of Mass: X=971, Y=723
# Frame 6 - Track ID: 27
#   YOLO Bounding Box: Top Left: (57, 1504), Bottom Right: (1074, 1988)
#   Mask Area: 3006
#   Center of Mass: X=190, Y=585
# Frame 6 - Track ID: 28
#   YOLO Bounding Box: Top Left: (3559, 2531), Bottom Right: (4287, 2796)
#   Mask Area: 1743
#   Center of Mass: X=1295, Y=899
# Frame 6 - Track ID: 29
#   YOLO Bounding Box: Top Left: (4667, 1099), Bottom Right: (5143, 1588)
#   Mask Area: 768
#   Center of Mass: X=1628, Y=434
# Frame 6 - Track ID: 30
#   YOLO Bounding Box: Top Left: (1479, 5), Bottom Right: (1655, 101)
#   Mask Area: 153
#   Center of Mass: X=524, Y=16
# Frame 6 - Track ID: 31
#   YOLO Bounding Box: Top Left: (1954, 2210), Bottom Right: (2095, 2351)
#   Mask Area: 211
#   Center of Mass: X=674, Y=766
#
# 0: 320x640 19 Clouds, 763.8ms
# Speed: 2.0ms preprocess, 763.8ms inference, 26.0ms postprocess per image at shape (1, 3, 320, 640)
# Frame 7 - Track ID: 1
#   YOLO Bounding Box: Top Left: (4415, 1517), Bottom Right: (5755, 2792)
#   Mask Area: 3093
#   Center of Mass: X=1721, Y=794
# Frame 7 - Track ID: 14
#   YOLO Bounding Box: Top Left: (100, 1505), Bottom Right: (2155, 2796)
#   Mask Area: 8228
#   Center of Mass: X=390, Y=719
# Frame 7 - Track ID: 15
#   YOLO Bounding Box: Top Left: (929, 389), Bottom Right: (1589, 782)
#   Mask Area: 1650
#   Center of Mass: X=414, Y=207
# Frame 7 - Track ID: 16
#   YOLO Bounding Box: Top Left: (2025, 951), Bottom Right: (3472, 2070)
#   Mask Area: 12438
#   Center of Mass: X=899, Y=526
# Frame 7 - Track ID: 17
#   YOLO Bounding Box: Top Left: (653, 509), Bottom Right: (938, 725)
#   Mask Area: 389
#   Center of Mass: X=259, Y=210
# Frame 7 - Track ID: 18
#   YOLO Bounding Box: Top Left: (4953, 760), Bottom Right: (5213, 1084)
#   Mask Area: 727
#   Center of Mass: X=1696, Y=309
# Frame 7 - Track ID: 19
#   YOLO Bounding Box: Top Left: (8, 7), Bottom Right: (538, 242)
#   Mask Area: 604
#   Center of Mass: X=104, Y=33
# Frame 7 - Track ID: 20
#   YOLO Bounding Box: Top Left: (2400, 20), Bottom Right: (2996, 281)
#   Mask Area: 922
#   Center of Mass: X=897, Y=58
# Frame 7 - Track ID: 21
#   YOLO Bounding Box: Top Left: (5597, 1100), Bottom Right: (5724, 1359)
#   Mask Area: 324
#   Center of Mass: X=1883, Y=412
# Frame 7 - Track ID: 24
#   YOLO Bounding Box: Top Left: (1808, 13), Bottom Right: (2260, 143)
#   Mask Area: 588
#   Center of Mass: X=675, Y=22
# Frame 7 - Track ID: 25
#   YOLO Bounding Box: Top Left: (45, 160), Bottom Right: (405, 696)
#   Mask Area: 1613
#   Center of Mass: X=57, Y=138
# Frame 7 - Track ID: 26
#   YOLO Bounding Box: Top Left: (2785, 2088), Bottom Right: (3055, 2213)
#   Mask Area: 558
#   Center of Mass: X=980, Y=723
# Frame 7 - Track ID: 27
#   YOLO Bounding Box: Top Left: (67, 1504), Bottom Right: (1059, 1975)
#   Mask Area: 2970
#   Center of Mass: X=192, Y=585
# Frame 7 - Track ID: 28
#   YOLO Bounding Box: Top Left: (3577, 2531), Bottom Right: (4304, 2796)
#   Mask Area: 1820
#   Center of Mass: X=1305, Y=900
# Frame 7 - Track ID: 29
#   YOLO Bounding Box: Top Left: (4667, 1087), Bottom Right: (5158, 1590)
#   Mask Area: 780
#   Center of Mass: X=1628, Y=432
# Frame 7 - Track ID: 30
#   YOLO Bounding Box: Top Left: (1475, 5), Bottom Right: (1656, 103)
#   Mask Area: 166
#   Center of Mass: X=524, Y=17
# Frame 7 - Track ID: 31
#   YOLO Bounding Box: Top Left: (1960, 2212), Bottom Right: (2100, 2352)
#   Mask Area: 211
#   Center of Mass: X=675, Y=765
# Frame 7 - Track ID: 32
#   YOLO Bounding Box: Top Left: (1737, 990), Bottom Right: (2029, 1180)
#   Mask Area: 286
#   Center of Mass: X=625, Y=370
# Frame 7 - Track ID: 33
#   YOLO Bounding Box: Top Left: (1975, 2070), Bottom Right: (2680, 2584)
#   Mask Area: 1854
#   Center of Mass: X=788, Y=759
#
# 0: 320x640 19 Clouds, 763.2ms
# Speed: 2.4ms preprocess, 763.2ms inference, 31.0ms postprocess per image at shape (1, 3, 320, 640)
# Frame 8 - Track ID: 1
#   YOLO Bounding Box: Top Left: (4439, 1533), Bottom Right: (5756, 2787)
#   Mask Area: 3107
#   Center of Mass: X=1722, Y=792
# Frame 8 - Track ID: 14
#   YOLO Bounding Box: Top Left: (91, 1498), Bottom Right: (2165, 2796)
#   Mask Area: 9076
#   Center of Mass: X=402, Y=721
# Frame 8 - Track ID: 15
#   YOLO Bounding Box: Top Left: (892, 385), Bottom Right: (1559, 779)
#   Mask Area: 1626
#   Center of Mass: X=410, Y=205
# Frame 8 - Track ID: 16
#   YOLO Bounding Box: Top Left: (2024, 945), Bottom Right: (3493, 2078)
#   Mask Area: 12347
#   Center of Mass: X=901, Y=528
# Frame 8 - Track ID: 17
#   YOLO Bounding Box: Top Left: (646, 505), Bottom Right: (929, 719)
#   Mask Area: 410
#   Center of Mass: X=261, Y=211
# Frame 8 - Track ID: 18
#   YOLO Bounding Box: Top Left: (4942, 757), Bottom Right: (5221, 1104)
#   Mask Area: 766
#   Center of Mass: X=1696, Y=313
# Frame 8 - Track ID: 19
#   YOLO Bounding Box: Top Left: (0, 8), Bottom Right: (528, 244)
#   Mask Area: 619
#   Center of Mass: X=104, Y=34
# Frame 8 - Track ID: 20
#   YOLO Bounding Box: Top Left: (2404, 23), Bottom Right: (2994, 284)
#   Mask Area: 921
#   Center of Mass: X=900, Y=58
# Frame 8 - Track ID: 21
#   YOLO Bounding Box: Top Left: (5602, 1098), Bottom Right: (5728, 1357)
#   Mask Area: 266
#   Center of Mass: X=1886, Y=410
# Frame 8 - Track ID: 24
#   YOLO Bounding Box: Top Left: (1796, 13), Bottom Right: (2249, 144)
#   Mask Area: 577
#   Center of Mass: X=676, Y=22
# Frame 8 - Track ID: 25
#   YOLO Bounding Box: Top Left: (68, 164), Bottom Right: (370, 601)
#   Mask Area: 1383
#   Center of Mass: X=58, Y=131
# Frame 8 - Track ID: 26
#   YOLO Bounding Box: Top Left: (2786, 2094), Bottom Right: (3072, 2224)
#   Mask Area: 551
#   Center of Mass: X=985, Y=722
# Frame 8 - Track ID: 27
#   YOLO Bounding Box: Top Left: (77, 1505), Bottom Right: (1048, 1965)
#   Mask Area: 2980
#   Center of Mass: X=191, Y=584
# Frame 8 - Track ID: 28
#   YOLO Bounding Box: Top Left: (3599, 2532), Bottom Right: (4322, 2796)
#   Mask Area: 1738
#   Center of Mass: X=1310, Y=902
# Frame 8 - Track ID: 29
#   YOLO Bounding Box: Top Left: (4678, 1085), Bottom Right: (5104, 1521)
#   Mask Area: 760
#   Center of Mass: X=1627, Y=431
# Frame 8 - Track ID: 30
#   YOLO Bounding Box: Top Left: (1472, 4), Bottom Right: (1655, 103)
#   Mask Area: 156
#   Center of Mass: X=526, Y=17
# Frame 8 - Track ID: 31
#   YOLO Bounding Box: Top Left: (1963, 2212), Bottom Right: (2105, 2353)
#   Mask Area: 260
#   Center of Mass: X=682, Y=768
# Frame 8 - Track ID: 32
#   YOLO Bounding Box: Top Left: (1727, 979), Bottom Right: (2039, 1182)
#   Mask Area: 333
#   Center of Mass: X=626, Y=368
# Frame 8 - Track ID: 33
#   YOLO Bounding Box: Top Left: (1991, 2074), Bottom Right: (2689, 2583)
#   Mask Area: 2229
#   Center of Mass: X=780, Y=775
#
# 0: 320x640 19 Clouds, 763.5ms
# Speed: 11.7ms preprocess, 763.5ms inference, 27.5ms postprocess per image at shape (1, 3, 320, 640)
# Frame 9 - Track ID: 1
#   YOLO Bounding Box: Top Left: (4465, 1548), Bottom Right: (5759, 2781)
#   Mask Area: 3506
#   Center of Mass: X=1729, Y=813
# Frame 9 - Track ID: 14
#   YOLO Bounding Box: Top Left: (695, 1840), Bottom Right: (2217, 2795)
#   Mask Area: 4393
#   Center of Mass: X=516, Y=835
# Frame 9 - Track ID: 15
#   YOLO Bounding Box: Top Left: (888, 393), Bottom Right: (1536, 772)
#   Mask Area: 1577
#   Center of Mass: X=407, Y=203
# Frame 9 - Track ID: 16
#   YOLO Bounding Box: Top Left: (2023, 938), Bottom Right: (3514, 2085)
#   Mask Area: 12304
#   Center of Mass: X=902, Y=528
# Frame 9 - Track ID: 17
#   YOLO Bounding Box: Top Left: (634, 504), Bottom Right: (914, 716)
#   Mask Area: 402
#   Center of Mass: X=255, Y=205
# Frame 9 - Track ID: 18
#   YOLO Bounding Box: Top Left: (4996, 844), Bottom Right: (5216, 1114)
#   Mask Area: 409
#   Center of Mass: X=1702, Y=336
# Frame 9 - Track ID: 19
#   YOLO Bounding Box: Top Left: (0, 6), Bottom Right: (527, 248)
#   Mask Area: 634
#   Center of Mass: X=103, Y=35
# Frame 9 - Track ID: 20
#   YOLO Bounding Box: Top Left: (2410, 24), Bottom Right: (2982, 279)
#   Mask Area: 890
#   Center of Mass: X=901, Y=58
# Frame 9 - Track ID: 21
#   YOLO Bounding Box: Top Left: (5607, 1096), Bottom Right: (5725, 1337)
#   Mask Area: 248
#   Center of Mass: X=1890, Y=403
# Frame 9 - Track ID: 24
#   YOLO Bounding Box: Top Left: (1803, 14), Bottom Right: (2262, 147)
#   Mask Area: 580
#   Center of Mass: X=679, Y=22
# Frame 9 - Track ID: 25
#   YOLO Bounding Box: Top Left: (61, 153), Bottom Right: (363, 580)
#   Mask Area: 1362
#   Center of Mass: X=54, Y=130
# Frame 9 - Track ID: 26
#   YOLO Bounding Box: Top Left: (2788, 2098), Bottom Right: (3089, 2231)
#   Mask Area: 637
#   Center of Mass: X=989, Y=724
# Frame 9 - Track ID: 27
#   YOLO Bounding Box: Top Left: (99, 1505), Bottom Right: (1050, 1953)
#   Mask Area: 2966
#   Center of Mass: X=191, Y=583
# Frame 9 - Track ID: 28
#   YOLO Bounding Box: Top Left: (3625, 2531), Bottom Right: (4349, 2796)
#   Mask Area: 1681
#   Center of Mass: X=1319, Y=902
# Frame 9 - Track ID: 29
#   YOLO Bounding Box: Top Left: (4694, 1101), Bottom Right: (5096, 1511)
#   Mask Area: 745
#   Center of Mass: X=1626, Y=429
# Frame 9 - Track ID: 30
#   YOLO Bounding Box: Top Left: (1477, 0), Bottom Right: (1648, 93)
#   Mask Area: 181
#   Center of Mass: X=520, Y=16
# Frame 9 - Track ID: 31
#   YOLO Bounding Box: Top Left: (1965, 2210), Bottom Right: (2115, 2360)
#   Mask Area: 230
#   Center of Mass: X=683, Y=763
# Frame 9 - Track ID: 32
#   YOLO Bounding Box: Top Left: (1726, 974), Bottom Right: (2049, 1186)
#   Mask Area: 341
#   Center of Mass: X=628, Y=368
# Frame 9 - Track ID: 33
#   YOLO Bounding Box: Top Left: (2009, 2083), Bottom Right: (2696, 2584)
#   Mask Area: 2367
#   Center of Mass: X=781, Y=781
#
# 0: 320x640 19 Clouds, 757.7ms
# Speed: 2.0ms preprocess, 757.7ms inference, 31.0ms postprocess per image at shape (1, 3, 320, 640)
# Frame 10 - Track ID: 1
#   YOLO Bounding Box: Top Left: (4492, 1546), Bottom Right: (5745, 2737)
#   Mask Area: 2416
#   Center of Mass: X=1757, Y=834
# Frame 10 - Track ID: 14
#   YOLO Bounding Box: Top Left: (931, 1958), Bottom Right: (2260, 2796)
#   Mask Area: 4540
#   Center of Mass: X=523, Y=833
# Frame 10 - Track ID: 15
#   YOLO Bounding Box: Top Left: (888, 404), Bottom Right: (1521, 767)
#   Mask Area: 1536
#   Center of Mass: X=401, Y=204
# Frame 10 - Track ID: 16
#   YOLO Bounding Box: Top Left: (2018, 943), Bottom Right: (3513, 2087)
#   Mask Area: 12089
#   Center of Mass: X=901, Y=529
# Frame 10 - Track ID: 17
#   YOLO Bounding Box: Top Left: (629, 504), Bottom Right: (898, 706)
#   Mask Area: 352
#   Center of Mass: X=251, Y=201
# Frame 10 - Track ID: 18
#   YOLO Bounding Box: Top Left: (5016, 874), Bottom Right: (5218, 1120)
#   Mask Area: 397
#   Center of Mass: X=1701, Y=336
# Frame 10 - Track ID: 19
#   YOLO Bounding Box: Top Left: (0, 4), Bottom Right: (528, 252)
#   Mask Area: 662
#   Center of Mass: X=101, Y=36
# Frame 10 - Track ID: 20
#   YOLO Bounding Box: Top Left: (2406, 23), Bottom Right: (2977, 279)
#   Mask Area: 864
#   Center of Mass: X=903, Y=59
# Frame 10 - Track ID: 21
#   YOLO Bounding Box: Top Left: (5595, 1089), Bottom Right: (5723, 1351)
#   Mask Area: 278
#   Center of Mass: X=1890, Y=410
# Frame 10 - Track ID: 25
#   YOLO Bounding Box: Top Left: (86, 151), Bottom Right: (321, 464)
#   Mask Area: 934
#   Center of Mass: X=54, Y=95
# Frame 10 - Track ID: 26
#   YOLO Bounding Box: Top Left: (2785, 2095), Bottom Right: (3107, 2235)
#   Mask Area: 681
#   Center of Mass: X=993, Y=728
# Frame 10 - Track ID: 27
#   YOLO Bounding Box: Top Left: (127, 1506), Bottom Right: (1048, 1936)
#   Mask Area: 2888
#   Center of Mass: X=192, Y=582
# Frame 10 - Track ID: 28
#   YOLO Bounding Box: Top Left: (3648, 2528), Bottom Right: (4377, 2796)
#   Mask Area: 1758
#   Center of Mass: X=1330, Y=901
# Frame 10 - Track ID: 29
#   YOLO Bounding Box: Top Left: (4703, 1111), Bottom Right: (5096, 1507)
#   Mask Area: 820
#   Center of Mass: X=1627, Y=428
# Frame 10 - Track ID: 30
#   YOLO Bounding Box: Top Left: (1477, 0), Bottom Right: (1639, 86)
#   Mask Area: 198
#   Center of Mass: X=520, Y=18
# Frame 10 - Track ID: 31
#   YOLO Bounding Box: Top Left: (1972, 2209), Bottom Right: (2126, 2365)
#   Mask Area: 216
#   Center of Mass: X=683, Y=761
# Frame 10 - Track ID: 32
#   YOLO Bounding Box: Top Left: (1726, 973), Bottom Right: (2060, 1191)
#   Mask Area: 346
#   Center of Mass: X=626, Y=364
# Frame 10 - Track ID: 33
#   YOLO Bounding Box: Top Left: (2013, 2088), Bottom Right: (2697, 2588)
#   Mask Area: 2419
#   Center of Mass: X=783, Y=782
# Frame 10 - Track ID: 35
#   YOLO Bounding Box: Top Left: (4549, 0), Bottom Right: (5750, 581)
#   Mask Area: 4747
#   Center of Mass: X=1746, Y=77
#
# 0: 320x640 19 Clouds, 763.0ms
# Speed: 2.3ms preprocess, 763.0ms inference, 29.0ms postprocess per image at shape (1, 3, 320, 640)
# Frame 11 - Track ID: 1
#   YOLO Bounding Box: Top Left: (4619, 1551), Bottom Right: (5635, 2473)
#   Mask Area: 723
#   Center of Mass: X=1803, Y=694
# Frame 11 - Track ID: 14
#   YOLO Bounding Box: Top Left: (1007, 2001), Bottom Right: (2262, 2796)
#   Mask Area: 4331
#   Center of Mass: X=520, Y=834
# Frame 11 - Track ID: 15
#   YOLO Bounding Box: Top Left: (872, 390), Bottom Right: (1529, 763)
#   Mask Area: 1616
#   Center of Mass: X=395, Y=203
# Frame 11 - Track ID: 16
#   YOLO Bounding Box: Top Left: (1914, 847), Bottom Right: (3558, 2105)
#   Mask Area: 12209
#   Center of Mass: X=904, Y=530
# Frame 11 - Track ID: 17
#   YOLO Bounding Box: Top Left: (631, 502), Bottom Right: (873, 681)
#   Mask Area: 326
#   Center of Mass: X=247, Y=197
# Frame 11 - Track ID: 18
#   YOLO Bounding Box: Top Left: (5021, 884), Bottom Right: (5219, 1122)
#   Mask Area: 347
#   Center of Mass: X=1700, Y=336
# Frame 11 - Track ID: 19
#   YOLO Bounding Box: Top Left: (0, 5), Bottom Right: (528, 258)
#   Mask Area: 757
#   Center of Mass: X=102, Y=37
# Frame 11 - Track ID: 20
#   YOLO Bounding Box: Top Left: (2412, 23), Bottom Right: (2976, 277)
#   Mask Area: 793
#   Center of Mass: X=901, Y=60
# Frame 11 - Track ID: 21
#   YOLO Bounding Box: Top Left: (5589, 1085), Bottom Right: (5720, 1353)
#   Mask Area: 275
#   Center of Mass: X=1891, Y=408
# Frame 11 - Track ID: 26
#   YOLO Bounding Box: Top Left: (2835, 2097), Bottom Right: (3163, 2238)
#   Mask Area: 731
#   Center of Mass: X=1003, Y=729
# Frame 11 - Track ID: 27
#   YOLO Bounding Box: Top Left: (144, 1504), Bottom Right: (1054, 1925)
#   Mask Area: 2808
#   Center of Mass: X=194, Y=582
# Frame 11 - Track ID: 28
#   YOLO Bounding Box: Top Left: (3665, 2526), Bottom Right: (4398, 2796)
#   Mask Area: 1796
#   Center of Mass: X=1337, Y=903
# Frame 11 - Track ID: 29
#   YOLO Bounding Box: Top Left: (4727, 1131), Bottom Right: (5095, 1497)
#   Mask Area: 828
#   Center of Mass: X=1635, Y=433
# Frame 11 - Track ID: 30
#   YOLO Bounding Box: Top Left: (1475, 0), Bottom Right: (1637, 85)
#   Mask Area: 199
#   Center of Mass: X=519, Y=18
# Frame 11 - Track ID: 31
#   YOLO Bounding Box: Top Left: (1983, 2213), Bottom Right: (2137, 2368)
#   Mask Area: 202
#   Center of Mass: X=687, Y=764
# Frame 11 - Track ID: 32
#   YOLO Bounding Box: Top Left: (1725, 968), Bottom Right: (2073, 1196)
#   Mask Area: 383
#   Center of Mass: X=631, Y=365
# Frame 11 - Track ID: 33
#   YOLO Bounding Box: Top Left: (2008, 2092), Bottom Right: (2692, 2592)
#   Mask Area: 1972
#   Center of Mass: X=792, Y=773
# Frame 11 - Track ID: 35
#   YOLO Bounding Box: Top Left: (4550, 0), Bottom Right: (5749, 580)
#   Mask Area: 4687
#   Center of Mass: X=1748, Y=76
# Frame 11 - Track ID: 36
#   YOLO Bounding Box: Top Left: (1941, 1825), Bottom Right: (2179, 2083)
#   Mask Area: 372
#   Center of Mass: X=683, Y=661
#
# 0: 320x640 20 Clouds, 770.9ms
# Speed: 2.3ms preprocess, 770.9ms inference, 30.0ms postprocess per image at shape (1, 3, 320, 640)
# Frame 12 - Track ID: 1
#   YOLO Bounding Box: Top Left: (4662, 1550), Bottom Right: (5605, 2375)
#   Mask Area: 954
#   Center of Mass: X=1712, Y=650
# Frame 12 - Track ID: 14
#   YOLO Bounding Box: Top Left: (1035, 2007), Bottom Right: (2275, 2796)
#   Mask Area: 4387
#   Center of Mass: X=522, Y=831
# Frame 12 - Track ID: 15
#   YOLO Bounding Box: Top Left: (850, 367), Bottom Right: (1542, 757)
#   Mask Area: 1728
#   Center of Mass: X=386, Y=195
# Frame 12 - Track ID: 16
#   YOLO Bounding Box: Top Left: (1901, 828), Bottom Right: (3557, 2092)
#   Mask Area: 12251
#   Center of Mass: X=902, Y=528
# Frame 12 - Track ID: 17
#   YOLO Bounding Box: Top Left: (620, 502), Bottom Right: (825, 652)
#   Mask Area: 367
#   Center of Mass: X=238, Y=195
# Frame 12 - Track ID: 18
#   YOLO Bounding Box: Top Left: (4949, 798), Bottom Right: (5233, 1137)
#   Mask Area: 806
#   Center of Mass: X=1686, Y=311
# Frame 12 - Track ID: 19
#   YOLO Bounding Box: Top Left: (0, 4), Bottom Right: (530, 261)
#   Mask Area: 807
#   Center of Mass: X=102, Y=38
# Frame 12 - Track ID: 20
#   YOLO Bounding Box: Top Left: (2420, 25), Bottom Right: (2975, 277)
#   Mask Area: 763
#   Center of Mass: X=900, Y=60
# Frame 12 - Track ID: 21
#   YOLO Bounding Box: Top Left: (5580, 1080), Bottom Right: (5716, 1355)
#   Mask Area: 340
#   Center of Mass: X=1887, Y=405
# Frame 12 - Track ID: 26
#   YOLO Bounding Box: Top Left: (2858, 2095), Bottom Right: (3207, 2244)
#   Mask Area: 730
#   Center of Mass: X=1013, Y=729
# Frame 12 - Track ID: 27
#   YOLO Bounding Box: Top Left: (185, 1500), Bottom Right: (1041, 1890)
#   Mask Area: 2714
#   Center of Mass: X=191, Y=580
# Frame 12 - Track ID: 28
#   YOLO Bounding Box: Top Left: (3679, 2520), Bottom Right: (4429, 2796)
#   Mask Area: 1866
#   Center of Mass: X=1350, Y=904
# Frame 12 - Track ID: 29
#   YOLO Bounding Box: Top Left: (4755, 1138), Bottom Right: (5115, 1494)
#   Mask Area: 669
#   Center of Mass: X=1638, Y=432
# Frame 12 - Track ID: 30
#   YOLO Bounding Box: Top Left: (1469, 0), Bottom Right: (1633, 85)
#   Mask Area: 215
#   Center of Mass: X=519, Y=19
# Frame 12 - Track ID: 31
#   YOLO Bounding Box: Top Left: (1991, 2212), Bottom Right: (2151, 2373)
#   Mask Area: 221
#   Center of Mass: X=689, Y=764
# Frame 12 - Track ID: 32
#   YOLO Bounding Box: Top Left: (1727, 962), Bottom Right: (2086, 1197)
#   Mask Area: 380
#   Center of Mass: X=631, Y=363
# Frame 12 - Track ID: 33
#   YOLO Bounding Box: Top Left: (2013, 2100), Bottom Right: (2690, 2595)
#   Mask Area: 2037
#   Center of Mass: X=796, Y=777
# Frame 12 - Track ID: 35
#   YOLO Bounding Box: Top Left: (4552, 0), Bottom Right: (5749, 579)
#   Mask Area: 4751
#   Center of Mass: X=1748, Y=76
# Frame 12 - Track ID: 36
#   YOLO Bounding Box: Top Left: (1935, 1830), Bottom Right: (2177, 2092)
#   Mask Area: 363
#   Center of Mass: X=684, Y=662
# Frame 12 - Track ID: 37
#   YOLO Bounding Box: Top Left: (5328, 2558), Bottom Right: (5760, 2794)
#   Mask Area: 970
#   Center of Mass: X=1860, Y=906
#
# 0: 320x640 20 Clouds, 760.4ms
# Speed: 3.0ms preprocess, 760.4ms inference, 34.0ms postprocess per image at shape (1, 3, 320, 640)
# Frame 13 - Track ID: 1
#   YOLO Bounding Box: Top Left: (4686, 1550), Bottom Right: (5595, 2316)
#   Mask Area: 1146
#   Center of Mass: X=1692, Y=638
# Frame 13 - Track ID: 14
#   YOLO Bounding Box: Top Left: (983, 1980), Bottom Right: (2265, 2796)
# ...
#   YOLO Bounding Box: Top Left: (1187, 1113), Bottom Right: (3370, 2383)
#   Mask Area: 17749
#   Center of Mass: X=773, Y=616
# Frame 36 - Track ID: 411
#   YOLO Bounding Box: Top Left: (1843, 1481), Bottom Right: (1987, 1672)
#   Mask Area: 174
#   Center of Mass: X=635, Y=534
# Frame 36 - Track ID: 410
#   YOLO Bounding Box: Top Left: (3608, 1199), Bottom Right: (5760, 2776)
#   Mask Area: 13822
#   Center of Mass: X=1705, Y=595
# Frame 36 - Track ID: 285
#   YOLO Bounding Box: Top Left: (1058, 1122), Bottom Right: (5760, 2699)
#   Mask Area: 35959
#   Center of Mass: X=1178, Y=607
# Frame 36 - Track ID: 407
#   YOLO Bounding Box: Top Left: (3627, 1396), Bottom Right: (4089, 1622)
#   Mask Area: 1106
#   Center of Mass: X=1279, Y=508
#
# 0: 320x640 5 Clouds, 867.5ms
# Speed: 3.0ms preprocess, 867.5ms inference, 10.0ms postprocess per image at shape (1, 3, 320, 640)
# Frame 37 - Track ID: 403
#   YOLO Bounding Box: Top Left: (5005, 2211), Bottom Right: (5486, 2748)
#   Mask Area: 1773
#   Center of Mass: X=1742, Y=834
# Frame 37 - Track ID: 394
#   YOLO Bounding Box: Top Left: (1179, 1123), Bottom Right: (3362, 2380)
#   Mask Area: 16974
#   Center of Mass: X=781, Y=624
# Frame 37 - Track ID: 410
#   YOLO Bounding Box: Top Left: (3682, 1211), Bottom Right: (5760, 2776)
#   Mask Area: 14010
#   Center of Mass: X=1708, Y=596
# Frame 37 - Track ID: 285
#   YOLO Bounding Box: Top Left: (1019, 1114), Bottom Right: (5755, 2707)
#   Mask Area: 36830
#   Center of Mass: X=1188, Y=609
# Frame 37 - Track ID: 407
#   YOLO Bounding Box: Top Left: (3626, 1393), Bottom Right: (4108, 1622)
#   Mask Area: 1072
#   Center of Mass: X=1279, Y=509
#
# 0: 320x640 6 Clouds, 881.7ms
# Speed: 3.0ms preprocess, 881.7ms inference, 12.0ms postprocess per image at shape (1, 3, 320, 640)
# Frame 38 - Track ID: 403
#   YOLO Bounding Box: Top Left: (5011, 2218), Bottom Right: (5480, 2746)
#   Mask Area: 1387
#   Center of Mass: X=1745, Y=850
# Frame 38 - Track ID: 394
#   YOLO Bounding Box: Top Left: (1264, 1169), Bottom Right: (3379, 2378)
#   Mask Area: 16620
#   Center of Mass: X=784, Y=629
# Frame 38 - Track ID: 410
#   YOLO Bounding Box: Top Left: (3754, 1216), Bottom Right: (5760, 2750)
#   Mask Area: 13563
#   Center of Mass: X=1710, Y=592
# Frame 38 - Track ID: 285
#   YOLO Bounding Box: Top Left: (1136, 1151), Bottom Right: (5760, 2713)
#   Mask Area: 35277
#   Center of Mass: X=1194, Y=610
# Frame 38 - Track ID: 407
#   YOLO Bounding Box: Top Left: (3610, 1387), Bottom Right: (4131, 1631)
#   Mask Area: 1081
#   Center of Mass: X=1278, Y=509
# Frame 38 - Track ID: 402
#   YOLO Bounding Box: Top Left: (1092, 1127), Bottom Right: (1655, 1520)
#   Mask Area: 797
#   Center of Mass: X=445, Y=430
#
# 0: 320x640 6 Clouds, 870.5ms
# Speed: 2.1ms preprocess, 870.5ms inference, 11.0ms postprocess per image at shape (1, 3, 320, 640)
# Frame 39 - Track ID: 403
#   YOLO Bounding Box: Top Left: (5038, 2197), Bottom Right: (5528, 2745)
#   Mask Area: 1847
#   Center of Mass: X=1745, Y=834
# Frame 39 - Track ID: 394
#   YOLO Bounding Box: Top Left: (1211, 1133), Bottom Right: (3402, 2382)
#   Mask Area: 17391
#   Center of Mass: X=779, Y=625
# Frame 39 - Track ID: 410
#   YOLO Bounding Box: Top Left: (4032, 1210), Bottom Right: (5760, 2392)
#   Mask Area: 11330
#   Center of Mass: X=1710, Y=559
# Frame 39 - Track ID: 285
#   YOLO Bounding Box: Top Left: (1111, 1155), Bottom Right: (5729, 2715)
#   Mask Area: 36074
#   Center of Mass: X=1179, Y=610
# Frame 39 - Track ID: 407
#   YOLO Bounding Box: Top Left: (3592, 1383), Bottom Right: (4172, 1654)
#   Mask Area: 1164
#   Center of Mass: X=1277, Y=511
# Frame 39 - Track ID: 402
#   YOLO Bounding Box: Top Left: (1095, 1111), Bottom Right: (1625, 1493)
#   Mask Area: 749
#   Center of Mass: X=448, Y=425
#
# 0: 320x640 6 Clouds, 863.4ms
# Speed: 2.4ms preprocess, 863.4ms inference, 13.0ms postprocess per image at shape (1, 3, 320, 640)
# Frame 40 - Track ID: 403
#   YOLO Bounding Box: Top Left: (5042, 2181), Bottom Right: (5549, 2745)
#   Mask Area: 1945
#   Center of Mass: X=1750, Y=830
# Frame 40 - Track ID: 394
#   YOLO Bounding Box: Top Left: (1218, 1134), Bottom Right: (3418, 2387)
#   Mask Area: 17011
#   Center of Mass: X=769, Y=627
# Frame 40 - Track ID: 410
#   YOLO Bounding Box: Top Left: (4143, 1204), Bottom Right: (5760, 2247)
#   Mask Area: 10719
#   Center of Mass: X=1715, Y=558
# Frame 40 - Track ID: 285
#   YOLO Bounding Box: Top Left: (1057, 1111), Bottom Right: (5760, 2724)
#   Mask Area: 37097
#   Center of Mass: X=1176, Y=608
# Frame 40 - Track ID: 407
#   YOLO Bounding Box: Top Left: (3564, 1388), Bottom Right: (4145, 1661)
#   Mask Area: 992
#   Center of Mass: X=1261, Y=509
# Frame 40 - Track ID: 402
#   YOLO Bounding Box: Top Left: (1128, 1104), Bottom Right: (1620, 1468)
#   Mask Area: 737
#   Center of Mass: X=455, Y=419
#
# 0: 320x640 5 Clouds, 873.8ms
# Speed: 3.0ms preprocess, 873.8ms inference, 11.0ms postprocess per image at shape (1, 3, 320, 640)
# Frame 41 - Track ID: 403
#   YOLO Bounding Box: Top Left: (5033, 2188), Bottom Right: (5533, 2747)
#   Mask Area: 1626
#   Center of Mass: X=1747, Y=836
# Frame 41 - Track ID: 394
#   YOLO Bounding Box: Top Left: (1204, 1118), Bottom Right: (3457, 2400)
#   Mask Area: 17623
#   Center of Mass: X=758, Y=621
# Frame 41 - Track ID: 410
#   YOLO Bounding Box: Top Left: (4175, 1201), Bottom Right: (5760, 2211)
#   Mask Area: 10591
#   Center of Mass: X=1721, Y=558
# Frame 41 - Track ID: 285
#   YOLO Bounding Box: Top Left: (1021, 1074), Bottom Right: (5760, 2724)
#   Mask Area: 37729
#   Center of Mass: X=1172, Y=606
# Frame 41 - Track ID: 407
#   YOLO Bounding Box: Top Left: (3525, 1401), Bottom Right: (4071, 1665)
#   Mask Area: 826
#   Center of Mass: X=1241, Y=517
#
# 0: 320x640 4 Clouds, 851.3ms
# Speed: 3.0ms preprocess, 851.3ms inference, 9.0ms postprocess per image at shape (1, 3, 320, 640)
# Frame 42 - Track ID: 394
#   YOLO Bounding Box: Top Left: (1168, 1113), Bottom Right: (3433, 2405)
#   Mask Area: 17615
#   Center of Mass: X=754, Y=615
# Frame 42 - Track ID: 410
#   YOLO Bounding Box: Top Left: (4184, 1198), Bottom Right: (5757, 2202)
#   Mask Area: 10057
#   Center of Mass: X=1728, Y=559
# Frame 42 - Track ID: 285
#   YOLO Bounding Box: Top Left: (1049, 1067), Bottom Right: (5760, 2710)
#   Mask Area: 38043
#   Center of Mass: X=1164, Y=602
# Frame 42 - Track ID: 407
#   YOLO Bounding Box: Top Left: (3508, 1409), Bottom Right: (4021, 1664)
#   Mask Area: 832
#   Center of Mass: X=1230, Y=514
#
# 0: 320x640 4 Clouds, 857.2ms
# Speed: 2.0ms preprocess, 857.2ms inference, 8.0ms postprocess per image at shape (1, 3, 320, 640)
# Frame 43 - Track ID: 394
#   YOLO Bounding Box: Top Left: (1084, 1066), Bottom Right: (3419, 2412)
#   Mask Area: 17781
#   Center of Mass: X=755, Y=616
# Frame 43 - Track ID: 410
#   YOLO Bounding Box: Top Left: (3976, 1199), Bottom Right: (5760, 2541)
#   Mask Area: 11061
#   Center of Mass: X=1731, Y=587
# Frame 43 - Track ID: 285
#   YOLO Bounding Box: Top Left: (971, 1012), Bottom Right: (5760, 2706)
#   Mask Area: 37408
#   Center of Mass: X=1158, Y=600
# Frame 43 - Track ID: 407
#   YOLO Bounding Box: Top Left: (3498, 1411), Bottom Right: (4002, 1669)
#   Mask Area: 837
#   Center of Mass: X=1226, Y=517
#
# 0: 320x640 3 Clouds, 872.7ms
# Speed: 3.0ms preprocess, 872.7ms inference, 11.5ms postprocess per image at shape (1, 3, 320, 640)
# Frame 44 - Track ID: 394
#   YOLO Bounding Box: Top Left: (1114, 1108), Bottom Right: (3382, 2418)
#   Mask Area: 18104
#   Center of Mass: X=754, Y=619
# Frame 44 - Track ID: 410
#   YOLO Bounding Box: Top Left: (3600, 1186), Bottom Right: (5760, 2695)
#   Mask Area: 14056
#   Center of Mass: X=1680, Y=583
# Frame 44 - Track ID: 285
#   YOLO Bounding Box: Top Left: (1046, 1075), Bottom Right: (5760, 2715)
#   Mask Area: 37487
#   Center of Mass: X=1164, Y=604
#
# 0: 320x640 4 Clouds, 897.2ms
# Speed: 3.0ms preprocess, 897.2ms inference, 11.1ms postprocess per image at shape (1, 3, 320, 640)
# Frame 45 - Track ID: 394
#   YOLO Bounding Box: Top Left: (1125, 1122), Bottom Right: (3377, 2424)
#   Mask Area: 18342
#   Center of Mass: X=759, Y=621
# Frame 45 - Track ID: 410
#   YOLO Bounding Box: Top Left: (3201, 1160), Bottom Right: (5620, 2719)
#   Mask Area: 21041
#   Center of Mass: X=1486, Y=597
# Frame 45 - Track ID: 285
#   YOLO Bounding Box: Top Left: (926, 966), Bottom Right: (5760, 2699)
#   Mask Area: 37646
#   Center of Mass: X=1161, Y=600
# Frame 45 - Track ID: 413
#   YOLO Bounding Box: Top Left: (3149, 2168), Bottom Right: (3588, 2284)
#   Mask Area: 321
#   Center of Mass: X=1108, Y=749
# Combined tracking data saved to Dataset/trajectories\6.csv
#
# 0: 320x640 22 Clouds, 863.7ms
# Speed: 2.0ms preprocess, 863.7ms inference, 15.0ms postprocess per image at shape (1, 3, 320, 640)
#
# 0: 320x640 2 Clouds, 889.4ms
# Speed: 2.0ms preprocess, 889.4ms inference, 17.0ms postprocess per image at shape (1, 3, 320, 640)
# Frame 2 - Track ID: 414
#   YOLO Bounding Box: Top Left: (5363, 96), Bottom Right: (5553, 241)
#   Mask Area: 229
#   Center of Mass: X=1815, Y=63
# Frame 2 - Track ID: 415
#   YOLO Bounding Box: Top Left: (4721, 2046), Bottom Right: (5040, 2339)
#   Mask Area: 498
#   Center of Mass: X=1629, Y=744
#
# 0: 320x640 3 Clouds, 873.5ms
# Speed: 3.0ms preprocess, 873.5ms inference, 16.0ms postprocess per image at shape (1, 3, 320, 640)
# Frame 3 - Track ID: 414
#   YOLO Bounding Box: Top Left: (5365, 100), Bottom Right: (5545, 238)
#   Mask Area: 215
#   Center of Mass: X=1815, Y=63
# Frame 3 - Track ID: 415
#   YOLO Bounding Box: Top Left: (4749, 2061), Bottom Right: (5048, 2335)
#   Mask Area: 377
#   Center of Mass: X=1632, Y=741
# Frame 3 - Track ID: 394
#   YOLO Bounding Box: Top Left: (918, 1618), Bottom Right: (2809, 2567)
#   Mask Area: 11551
#   Center of Mass: X=570, Y=744
#
# 0: 320x640 3 Clouds, 861.9ms
# Speed: 3.0ms preprocess, 861.9ms inference, 14.0ms postprocess per image at shape (1, 3, 320, 640)
# Frame 4 - Track ID: 414
#   YOLO Bounding Box: Top Left: (5366, 104), Bottom Right: (5540, 236)
#   Mask Area: 200
#   Center of Mass: X=1815, Y=63
# Frame 4 - Track ID: 415
#   YOLO Bounding Box: Top Left: (4776, 2071), Bottom Right: (5060, 2332)
#   Mask Area: 352
#   Center of Mass: X=1635, Y=740
# Frame 4 - Track ID: 394
#   YOLO Bounding Box: Top Left: (873, 1794), Bottom Right: (2756, 2625)
#   Mask Area: 11605
#   Center of Mass: X=596, Y=749
#
# 0: 320x640 1 Cloud, 847.5ms
# Speed: 2.0ms preprocess, 847.5ms inference, 13.0ms postprocess per image at shape (1, 3, 320, 640)
# Frame 5 - Track ID: 414
#   YOLO Bounding Box: Top Left: (5368, 107), Bottom Right: (5532, 233)
#   Mask Area: 188
#   Center of Mass: X=1814, Y=62
#
# 0: 320x640 1 Cloud, 862.0ms
# Speed: 2.0ms preprocess, 862.0ms inference, 13.0ms postprocess per image at shape (1, 3, 320, 640)
# Frame 6 - Track ID: 414
#   YOLO Bounding Box: Top Left: (5369, 114), Bottom Right: (5524, 234)
#   Mask Area: 169
#   Center of Mass: X=1812, Y=62
#
# 0: 320x640 2 Clouds, 847.5ms
# Speed: 3.0ms preprocess, 847.5ms inference, 14.0ms postprocess per image at shape (1, 3, 320, 640)
# Frame 7 - Track ID: 414
#   YOLO Bounding Box: Top Left: (5370, 122), Bottom Right: (5512, 230)
#   Mask Area: 189
#   Center of Mass: X=1810, Y=65
# Frame 7 - Track ID: 285
#   YOLO Bounding Box: Top Left: (925, 1586), Bottom Right: (4314, 2654)
#   Mask Area: 15727
#   Center of Mass: X=792, Y=769
#
# 0: 320x640 2 Clouds, 863.0ms
# Speed: 2.0ms preprocess, 863.0ms inference, 15.0ms postprocess per image at shape (1, 3, 320, 640)
# Frame 8 - Track ID: 414
#   YOLO Bounding Box: Top Left: (5366, 126), Bottom Right: (5507, 234)
#   Mask Area: 112
#   Center of Mass: X=1811, Y=67
# Frame 8 - Track ID: 285
#   YOLO Bounding Box: Top Left: (865, 1639), Bottom Right: (4397, 2665)
#   Mask Area: 15679
#   Center of Mass: X=808, Y=770
#
# 0: 320x640 1 Cloud, 1000.0ms
# Speed: 2.0ms preprocess, 1000.0ms inference, 13.6ms postprocess per image at shape (1, 3, 320, 640)
# Frame 9 - Track ID: 285
#   YOLO Bounding Box: Top Left: (879, 1825), Bottom Right: (4027, 2655)
#   Mask Area: 14885
#   Center of Mass: X=811, Y=772
#
# 0: 320x640 1 Cloud, 861.8ms
# Speed: 3.0ms preprocess, 861.8ms inference, 13.2ms postprocess per image at shape (1, 3, 320, 640)
# Frame 10 - Track ID: 285
#   YOLO Bounding Box: Top Left: (979, 1881), Bottom Right: (4137, 2639)
#   Mask Area: 14936
#   Center of Mass: X=821, Y=769
#
# 0: 320x640 1 Cloud, 861.3ms
# Speed: 3.0ms preprocess, 861.3ms inference, 11.5ms postprocess per image at shape (1, 3, 320, 640)
# Frame 11 - Track ID: 285
#   YOLO Bounding Box: Top Left: (854, 1851), Bottom Right: (4362, 2645)
#   Mask Area: 15326
#   Center of Mass: X=843, Y=772
#
# 0: 320x640 1 Cloud, 858.6ms
# Speed: 2.0ms preprocess, 858.6ms inference, 15.0ms postprocess per image at shape (1, 3, 320, 640)
# Frame 12 - Track ID: 285
#   YOLO Bounding Box: Top Left: (891, 1997), Bottom Right: (3740, 2628)
#   Mask Area: 8536
#   Center of Mass: X=750, Y=767
#
# 0: 320x640 1 Cloud, 858.9ms
# Speed: 3.0ms preprocess, 858.9ms inference, 12.0ms postprocess per image at shape (1, 3, 320, 640)
# Frame 13 - Track ID: 285
#   YOLO Bounding Box: Top Left: (1136, 2030), Bottom Right: (3966, 2634)
#   Mask Area: 10997
#   Center of Mass: X=920, Y=780
#
# 0: 320x640 2 Clouds, 846.1ms
# Speed: 2.0ms preprocess, 846.1ms inference, 14.0ms postprocess per image at shape (1, 3, 320, 640)
# Frame 14 - Track ID: 285
#   YOLO Bounding Box: Top Left: (241, 1862), Bottom Right: (3887, 2644)
#   Mask Area: 11039
#   Center of Mass: X=681, Y=758
# Frame 14 - Track ID: 417
#   YOLO Bounding Box: Top Left: (693, 1500), Bottom Right: (1675, 1736)
#   Mask Area: 1511
#   Center of Mass: X=379, Y=545
#
# 0: 320x640 4 Clouds, 853.7ms
# Speed: 3.0ms preprocess, 853.7ms inference, 11.0ms postprocess per image at shape (1, 3, 320, 640)
# Frame 15 - Track ID: 285
#   YOLO Bounding Box: Top Left: (660, 1948), Bottom Right: (4029, 2682)
#   Mask Area: 7431
#   Center of Mass: X=833, Y=776
# Frame 15 - Track ID: 417
#   YOLO Bounding Box: Top Left: (684, 1500), Bottom Right: (1696, 1744)
#   Mask Area: 1659
#   Center of Mass: X=382, Y=547
# Frame 15 - Track ID: 418
#   YOLO Bounding Box: Top Left: (4575, 2097), Bottom Right: (5021, 2440)
#   Mask Area: 672
#   Center of Mass: X=1597, Y=754
# Frame 15 - Track ID: 419
#   YOLO Bounding Box: Top Left: (3561, 2076), Bottom Right: (5358, 2792)
#   Mask Area: 4650
#   Center of Mass: X=1475, Y=844
#
# 0: 320x640 4 Clouds, 846.5ms
# Speed: 2.0ms preprocess, 846.5ms inference, 14.0ms postprocess per image at shape (1, 3, 320, 640)
# Frame 16 - Track ID: 285
#   YOLO Bounding Box: Top Left: (791, 1984), Bottom Right: (3984, 2698)
#   Mask Area: 5975
#   Center of Mass: X=770, Y=786
# Frame 16 - Track ID: 417
#   YOLO Bounding Box: Top Left: (667, 1494), Bottom Right: (1731, 1751)
#   Mask Area: 1845
#   Center of Mass: X=387, Y=549
# Frame 16 - Track ID: 418
#   YOLO Bounding Box: Top Left: (4593, 2084), Bottom Right: (5044, 2432)
#   Mask Area: 640
#   Center of Mass: X=1603, Y=751
# Frame 16 - Track ID: 419
#   YOLO Bounding Box: Top Left: (3545, 2055), Bottom Right: (5402, 2795)
#   Mask Area: 5319
#   Center of Mass: X=1489, Y=840
#
# 0: 320x640 4 Clouds, 848.4ms
# Speed: 2.0ms preprocess, 848.4ms inference, 17.0ms postprocess per image at shape (1, 3, 320, 640)
# Frame 17 - Track ID: 285
#   YOLO Bounding Box: Top Left: (931, 2015), Bottom Right: (3949, 2702)
#   Mask Area: 5790
#   Center of Mass: X=788, Y=786
# Frame 17 - Track ID: 417
#   YOLO Bounding Box: Top Left: (588, 1471), Bottom Right: (1790, 1763)
#   Mask Area: 1788
#   Center of Mass: X=387, Y=550
# Frame 17 - Track ID: 418
#   YOLO Bounding Box: Top Left: (4626, 2079), Bottom Right: (5070, 2422)
#   Mask Area: 616
#   Center of Mass: X=1616, Y=754
# Frame 17 - Track ID: 419
#   YOLO Bounding Box: Top Left: (3546, 2046), Bottom Right: (5417, 2794)
#   Mask Area: 5307
#   Center of Mass: X=1494, Y=838
#
# 0: 320x640 4 Clouds, 840.4ms
# Speed: 3.0ms preprocess, 840.4ms inference, 16.0ms postprocess per image at shape (1, 3, 320, 640)
# Frame 18 - Track ID: 285
#   YOLO Bounding Box: Top Left: (999, 2026), Bottom Right: (3905, 2706)
#   Mask Area: 6522
#   Center of Mass: X=821, Y=785
# Frame 18 - Track ID: 417
#   YOLO Bounding Box: Top Left: (570, 1463), Bottom Right: (1838, 1773)
#   Mask Area: 1915
#   Center of Mass: X=394, Y=553
# Frame 18 - Track ID: 418
#   YOLO Bounding Box: Top Left: (4635, 2061), Bottom Right: (5088, 2411)
#   Mask Area: 642
#   Center of Mass: X=1617, Y=747
# Frame 18 - Track ID: 419
#   YOLO Bounding Box: Top Left: (3614, 2049), Bottom Right: (5456, 2790)
#   Mask Area: 4893
#   Center of Mass: X=1514, Y=844
# Combined tracking data saved to Dataset/trajectories\8.csv
